# %% [markdown]
# # Imports/Downloads

# %%
import sys
# !{sys.executable} -m pip install pygraphviz
# !{sys.executable} -m pip install pydot
# Out:
# Collecting pygraphviz
#   Downloading pygraphviz-1.7.zip (118 kB)
#      |████████████████████████████████| 118 kB 720 kB/s eta 0:00:01
# Building wheels for collected packages: pygraphviz
#   Building wheel for pygraphviz (setup.py) ... done
#   Created wheel for pygraphviz: filename=pygraphviz-1.7-cp38-cp38-macosx_10_15_x86_64.whl size=101558 sha256=393aabd8c6bbae549b89f262ff1d1c1d5dac78b932400c5c4342854e907f8dd7
#   Stored in directory: /Users/francescoandreuzzi/Library/Caches/pip/wheels/77/c6/8b/566e1c26d0f9d41093e28d8e1768f1412d54846e3296114feb
# Successfully built pygraphviz
# Installing collected packages: pygraphviz
# Successfully installed pygraphviz-1.7
# WARNING: You are using pip version 21.0.1; however, version 21.1 is available.
# You should consider upgrading via the '/Users/francescoandreuzzi/.local/share/virtualenvs/parametric-dmd-FqHiOHMJ/bin/python -m pip install --upgrade pip' command.
# Collecting pydot
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: pyparsing>=2.1.4 in /Users/francescoandreuzzi/.local/share/virtualenvs/parametric-dmd-FqHiOHMJ/lib/python3.8/site-packages (from pydot) (2.4.7)
# Installing collected packages: pydot
# Successfully installed pydot-1.4.2
# WARNING: You are using pip version 21.0.1; however, version 21.1 is available.
# You should consider upgrading via the '/Users/francescoandreuzzi/.local/share/virtualenvs/parametric-dmd-FqHiOHMJ/bin/python -m pip install --upgrade pip' command.

# %%
import networkx as nx
import networkx.drawing.nx_pylab as nx_draw
from networkx.drawing.nx_agraph import to_agraph

from IPython.display import Image
import os

# %% [markdown]
# ## Tree graph

# %%
graph = nx.balanced_tree(3, 2, create_using=nx.DiGraph)

agraph = to_agraph(graph)
agraph.layout('dot')
agraph.draw('test.png')

img = Image(filename='test.png', width = 800, height = 400)
os.remove('test.png')

img
